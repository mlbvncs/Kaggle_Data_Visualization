# %% [markdown]
# 0. Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Carregando os dados

# %%
#Caminho do csv lido
spotify_filepath = "../data/spotify.csv"

#Lendo o arquivo dentro da variável
spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates=True)

# %% [markdown]
# 2. Plotando os dados

# %%
#Definindo altura e largura da figura
plt.figure(figsize=(16,6))

##Gráfico de linha mostrando como o o número de streams das músicas evoluiu ao longo do tempo
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %%
#Mudando o estilo da figura para o tema "dark"
sns.set_style("dark")
#Definindo altura e largura da figura
plt.figure(figsize=(16,6))

##Gráfico de linha mostrando como o o número de streams das músicas evoluiu ao longo do tempo
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Seaborn possui cinco temas diferentes: (1) "darkgrid", (2) "whitegrid", (3) "dark", (4) "white" e (5) "ticks". Para alterá-los, basta usar um comando semelhante ao da célula de código acima (com o tema escolhido preenchido).
