# %% [markdown]
# 0. Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Carregando os dados

# %%
#Caminho do csv lido
flight_filepath = "../data/flight_delays.csv"

#Lendo o arquivo dentro da variável
flight_data = pd.read_csv(flight_filepath, index_col="Month")

# %% [markdown]
# 2. Examinando os dados

# %%
#Imprimindo o conjunto de dados (completo, por ser pequeno)
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %% [markdown]
# 3. Plotando os dados

# %%
#Definindo altura e largura da figura e o título
plt.figure(figsize=(10,6))
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

#Gráfico de barras costuma ser usado para comparar valores entre categorias (sem continuidade entre os valores)
'''Em gráfico de barras, x = Variável categórica (grupos/categorias para comparar)
 e y = Variável numérica (valores para medir/comparar), agrupa os dados por x e 
 calcula a MÉDIA de y para cada grupo (por padrão).'''
#Gráfico de barras mostrando o delay de chegada médio para Spirit Airlines flights por mês
sns.barplot(x=flight_data.index, y=flight_data['NK'])

#Adicionando rótulo para o eixo vertical
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
#Definindo altura e largura da figura e o título
plt.figure(figsize=(14,7))
plt.title("Average Arrival Delay for Each Airline, by Month")

#Heatmap costuma ser usado para visualizar muitos dados ao mesmo tempo
#Heatmap mostrando a média de delay de chegada para cada empresa aérea por mês
sns.heatmap(data=flight_data, annot=True) # annot faz o heatmap mostrar os valores numéricos dentro de cada célula

#Adicionando rótulo para o eixo horizontal
plt.xlabel("Airline")
# Out:
# Text(0.5, 47.7222222222222, 'Airline')

# %% [markdown]
# Obs.: Que padrões é possível identificar na tabela? Os meses do final do ano (especialmente os meses 9 a 11) aparecem relativamente escuros para todas as companhias aéreas. Isso sugere que as companhias aéreas são melhores (em média) em cumprir seus horários durante esses meses!
